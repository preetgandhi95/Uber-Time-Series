# %%
import pandas as pd

# %%
df = pd.read_csv('uber-raw-data-janjune-15.csv')

# %%
df
# Out:
#          Dispatching_base_num          Pickup_date Affiliated_base_num  \
# 0                      B02617  2015-05-17 09:47:00              B02617
# 1                      B02617  2015-05-17 09:47:00              B02617
# 2                      B02617  2015-05-17 09:47:00              B02617
# 3                      B02617  2015-05-17 09:47:00              B02774
# 4                      B02617  2015-05-17 09:47:00              B02617
# 5                      B02617  2015-05-17 09:47:00              B02617
# 6                      B02617  2015-05-17 09:47:00              B02617
# 7                      B02617  2015-05-17 09:47:00              B02764
# 8                      B02617  2015-05-17 09:47:00              B02617
# 9                      B02617  2015-05-17 09:47:00              B02764
# 10                     B02617  2015-05-17 09:48:00              B02617
# 11                     B02617  2015-05-17 09:48:00              B02617
# ...

# %%
dff = pd.read_csv('try.txt',delimiter='\t',names=['locationID','Borough','Area'],header= None)

# %%
dff
# Out:
#      locationID        Borough                                 Area
# 0             2         Queens                          Jamaica Bay
# 1             3          Bronx              Allerton/Pelham Gardens
# 2             4      Manhattan                        Alphabet City
# 3             5  Staten Island                        Arden Heights
# 4             6  Staten Island              Arrochar/Fort Wadsworth
# 5             7         Queens                              Astoria
# 6             8         Queens                         Astoria Park
# 7             9         Queens                           Auburndale
# 8            10         Queens                         Baisley Park
# 9            11       Brooklyn                           Bath Beach
# 10           12      Manhattan                         Battery Park
# 11           13      Manhattan                    Battery Park City
# 12           14       Brooklyn                            Bay Ridge
# ...

# %%
df = df.merge(dff,on='locationID',how='inner')
df
# Out:
#          Dispatching_base_num          Pickup_date Affiliated_base_num  \
# 0                      B02617  2015-05-17 09:47:00              B02617
# 1                      B02617  2015-05-17 09:50:00              B02617
# 2                      B02617  2015-05-17 09:53:00              B02617
# 3                      B02617  2015-05-17 10:00:00              B02617
# 4                      B02617  2015-05-17 10:00:00              B02617
# 5                      B02617  2015-05-17 10:03:00              B00272
# 6                      B02617  2015-05-17 10:04:00              B02617
# 7                      B02617  2015-05-17 10:10:00              B02617
# 8                      B02617  2015-05-17 10:17:00              B02617
# 9                      B02617  2015-05-17 10:23:00              B02617
# 10                     B02617  2015-05-17 10:33:00              B02764
# 11                     B02598  2015-01-18 15:15:39              B02598
# ...

# %%
df.to_csv('data.csv')

# %%
df1 = pd.read_csv('uber-raw-data-apr14.csv')

# %%
df2 = pd.read_csv('uber-raw-data-may14.csv')

# %%
df3 = pd.read_csv('uber-raw-data-jun14.csv')

# %%
df4 = pd.read_csv('uber-raw-data-jul14.csv')

# %%
df5 = pd.read_csv('uber-raw-data-aug14.csv')

# %%
df6 = pd.read_csv('uber-raw-data-sep14.csv')

# %%
df14 = pd.concat([df1,df2,df3,df4,df5,df6])

# %%
df14
# Out:
#                   Date/Time      Lat      Lon    Base
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1          4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2          4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3          4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4          4/1/2014 0:33:00  40.7594 -73.9722  B02512
# 5          4/1/2014 0:33:00  40.7383 -74.0403  B02512
# 6          4/1/2014 0:39:00  40.7223 -73.9887  B02512
# 7          4/1/2014 0:45:00  40.7620 -73.9790  B02512
# 8          4/1/2014 0:55:00  40.7524 -73.9960  B02512
# 9          4/1/2014 1:01:00  40.7575 -73.9846  B02512
# 10         4/1/2014 1:19:00  40.7256 -73.9869  B02512
# 11         4/1/2014 1:48:00  40.7591 -73.9684  B02512
# 12         4/1/2014 1:49:00  40.7271 -73.9803  B02512
# 13         4/1/2014 2:11:00  40.6463 -73.7896  B02512
# 14         4/1/2014 2:25:00  40.7564 -73.9167  B02512
# 15         4/1/2014 2:31:00  40.7666 -73.9531  B02512
# ...
